# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:/Amazon Sales data.csv")

# %%
data.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
data.shape
# Out:
# (100, 14)

# %%
# Looking at the columns of the data...
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
# Looking at the information about the given data..
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
# Checking the null values..

data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %% [markdown]
# So there is no null values.

# %%
# Checking for the duplicate values 
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values in the data.

# %%
data['Country'].value_counts()
# Out:
# The Gambia               4
# Sierra Leone             3
# Sao Tome and Principe    3
# Mexico                   3
# Australia                3
#                         ..
# Comoros                  1
# Iceland                  1
# Macedonia                1
# Mauritania               1
# Mozambique               1
# Name: Country, Length: 76, dtype: int64

# %%
data['Item Type'].value_counts()
# Out:
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: Item Type, dtype: int64

# %%
plt.figure(figsize=(15,6))

sns.histplot(x= 'Item Type', data = data, color= 'orange')

plt.title("Histogram for the Item Type")
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(15,6))

sns.barplot(x= 'Item Type',y= 'Total Revenue', data = data, color= 'orange')

plt.title("Item Type v/s Total Revenue")
plt.grid(False)
plt.show()

# %%
data['Sales Channel'].value_counts()
# Out:
# Offline    50
# Online     50
# Name: Sales Channel, dtype: int64

# %% [markdown]
# There are Equal Number of sales came from the online and the offline mode (i.e. 50 from online and 50 from the offline).

# %%
data['Order Priority'].value_counts()
# Out:
# H    30
# L    27
# C    22
# M    21
# Name: Order Priority, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.histplot(x= 'Order Priority', data= data, color= 'red')
plt.title("Histogram for the Order Priority")
plt.grid(False)
plt.show()

# %% [markdown]
# ## Transform the Data

# %%
# Converting the 'Order Date' and 'Ship Data' from object to date time format.
data['Order Date']= pd.to_datetime(data['Order Date'])
data['Ship Date']= pd.to_datetime(data['Ship Date'])

# %%
# Checking the datatype of the columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    datetime64[ns]
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    datetime64[ns]
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 11.1+ KB

# %%
# Extracting Year and Month from the order date.

data['Order Month'] = data['Order Date'].dt.month
data['Order Year'] = data['Order Date'].dt.year

# %%
data[['Order Month', 'Order Year']]
# Out:
#     Order Month  Order Year
# 0             5        2010
# 1             8        2012
# 2             5        2014
# 3             6        2014
# 4             2        2013
# ..          ...         ...
# 95            7        2011
# 96           11        2011
# 97            6        2016
# 98            7        2015
# 99            2        2012
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Analysis of Sales Trend and Key Metrics:

# %% [markdown]
# ### Month wise Sales :

# %%
month_wise_sales = data.groupby('Order Month').agg({'Total Revenue': 'sum'}).reset_index()
print(month_wise_sales)
# Out:
#     Order Month  Total Revenue
# 0             1    10482467.12
# 1             2    24740517.77
# 2             3     2274823.87
# 3             4    16187186.33
# 4             5    13215739.99
# 5             6     5230325.77
# 6             7    15669518.50
# 7             8     1128164.91
# 8             9     5314762.56
# 9            10    15287576.61
# 10           11    20568222.76
# 11           12     7249462.12

# %% [markdown]
# ### Year wise Sales :

# %%
year_wise_sales = data.groupby('Order Year').agg({'Total Revenue': 'sum'}).reset_index()
print(year_wise_sales)
# Out:
#    Order Year  Total Revenue
# 0        2010    19186024.92
# 1        2011    11129166.07
# 2        2012    31898644.52
# 3        2013    20330448.66
# 4        2014    16630214.43
# 5        2015    12427982.86
# 6        2016    12372867.22
# 7        2017    13373419.63

# %% [markdown]
# ### Year Month Wise Sales :

# %%
yearly_month_wise_sales = data.groupby(['Order Year', 'Order Month']).agg({'Total Revenue': 'sum'}).reset_index()
print(yearly_month_wise_sales)
# Out:
#     Order Year  Order Month  Total Revenue
# 0         2010            2     3410661.12
# 1         2010            5     2587973.26
# 2         2010            6     1082418.40
# 3         2010           10     6064933.75
# 4         2010           11     3458252.00
# 5         2010           12     2581786.39
# 6         2011            1     1042225.35
# 7         2011            2      387002.20
# 8         2011            4     2798046.49
# 9         2011            5      272410.45
# 10        2011            6       19103.44
# 11        2011            7       97040.64
# 12        2011            9      574951.92
# 13        2011           11     5938385.58
# 14        2012            1     1012884.00
# 15        2012            2     6707849.42
# 16        2012            3      994765.42
# 17        2012            4     4556012.38
# 18        2012            5     3782781.82
# 19        2012            6     2132075.27
# 20        2012            7     4445093.92
# ...

# %%
# Month Wise Sales

plt.figure(figsize=(12,6))

sns.barplot(data=month_wise_sales, x= 'Order Month', y= 'Total Revenue', color='blue', alpha = 0.9)

plt.title("Month Wise Sales")
plt.xlabel("Months")
plt.ylabel("Total Revenue")

plt.show()

# %%
# Year Wise Sales

plt.figure(figsize=(12,6))

sns.barplot(data=year_wise_sales, x= 'Order Year', y= 'Total Revenue', color='purple', alpha = 0.9)

plt.title("Year Wise Sales")
plt.xlabel("Year")
plt.ylabel("Total Revenue")

plt.show()

# %%
# Year-Month Wise Sales

plt.figure(figsize=(14, 8))

for year in yearly_month_wise_sales['Order Year'].unique():
    monthly_data = yearly_month_wise_sales[yearly_month_wise_sales['Order Year'] == year]
    plt.plot(monthly_data['Order Month'], monthly_data['Total Revenue'], marker='o', label=str(year))

plt.title('Year-Month Wise Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.legend(title= 'Year')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Key Metrics:

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit',
#        'Order Month', 'Order Year'],
#       dtype='object')

# %%
# Finding the Total Revenue, Total Cost and Total Profit

total_revenue = data['Total Revenue'].sum()
total_cost = data['Total Cost'].sum()
total_profit = data['Total Profit'].sum()

print(f"Total Revenue : $ {round(total_revenue,2)}")
print(f"Total Cost : $ {round(total_cost,2)}")
print(f"Total Profit : $ {round(total_profit,2)}")
# Out:
# Total Revenue : $ 137348768.31
# Total Cost : $ 93180569.91
# Total Profit : $ 44168198.4

# %% [markdown]
# ### Correlation Matrix of the Attributes:

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(12,6))

sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap= 'coolwarm', linewidths=0.5)

plt.title("Correlation matrix of attributes")

plt.show()
# Out:
# C:\Users\asifi\AppData\Local\Temp\ipykernel_7200\2807527103.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %% [markdown]
# ### Top 5 countries having the Highest Sales and the Profit

# %%
# Aggregate total sales and total profit by country
country_sales_profit = data.groupby('Country').agg({'Total Revenue': 'sum', 'Total Profit': 'sum'}).reset_index()

# Sort by Total Revenue and Total Profit to find the top 5 countries
top5_sales_countries = country_sales_profit.nlargest(5, 'Total Revenue')
top5_profit_countries = country_sales_profit.nlargest(5, 'Total Profit')

# Set the style of the visualization
sns.set(style="whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(12, 14))

# Bar plot for top 5 countries by sales
sns.barplot(x='Total Revenue', y='Country', data=top5_sales_countries, ax=axes[0], palette='viridis')
axes[0].set_title('Top 5 Countries by Total Sales')
axes[0].set_xlabel('Total Sales')
axes[0].set_ylabel('Country')

# Bar plot for top 5 countries by profit
sns.barplot(x='Total Profit', y='Country', data=top5_profit_countries, ax=axes[1], palette='viridis')
axes[1].set_title('Top 5 Countries by Total Profit')
axes[1].set_xlabel('Total Profit')
axes[1].set_ylabel('Country')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# 1. The data given has 100 unique rows of data with 14 attributes.
# 2. Most Number of Item Types sold included Clothes and Cosmetics followed by office Supplies.
# 3. Highest Number of Revenue Generated from Item Type was from 'Household' and the lowest was from the 'Fruits'.
# 4. There are Equal Number of sales came from the online and the offline mode (i.e. 50 from online and 50 from the offline).
# 5. Given data has the most number of 'High' Order Priority, which means customers are likely to order for urgent deliveries.
# 6. Most Sales comes from the month of 'Febuary' and least comes from the month of 'August'.
# 7. Most Sales comes in the year of '2012'.
# 8. While looking at the Year-Month Wise Sales Trend, the highest revenue generated was from the month of 'JULY' in the year '2013', whereas the least revenue generated was from the month of 'AUGUST' and 'SEPTEMBER' in the year '2015' and '2014' respectively.
# 9. Total Revenue : $ 137,348,768.31 .
# 10. Total Cost : $ 93,180,569.91.
# 11. Total Profit : $ 44,168,198.40.
